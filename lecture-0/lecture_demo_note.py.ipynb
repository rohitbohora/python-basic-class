# %%
print("hello world")
# Out:
# hello world

# %%
print(2+2)
# Out:
# 4

# %%
print("2+2")
# Out:
# 2+2

# %%
print(8383884-777575+75757/747474*64646)
# Out:
# 7612860.916216483

# %%
a = 2+2

# %%
print("k cha boro khabar")
# Out:
# k cha boro khabar

# %%
print(a-2)
# Out:
# 2

# %%
input("whats your number" )
# Out:
# whats your number747477474
# '747477474'

# %%
num = input("whats your number ")
# Out:
# whats your number 888

# %%
print(num)
# Out:
# 888

# %%
n = input("what is your name ")
# Out:
# what is your name kshitij

# %%
print(n + " is very cute")
# Out:
# kshitij is very cute

# %%
na_me = input("what is your name ")
if na_me == "kshitij":
    print("you are so cute")
else:
    print("not that much yar")
# Out:
# what is your name asdfasf
# not that much yar

# %%
anss = input("ka gara ako? ")
if anss == "khelera ako":
    print("aja pitai khais")
elif anss == "padera ako":
    print("tero ama hu ma gaff nade")
elif anss == "khako gako thiye":
    print("kati bhannu momo nakha bhanera")
else:
    print("aja bachiyo")
# Out:
# ka gara ako? khelera ako
# aja pitai khais
